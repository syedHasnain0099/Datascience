# %%
import pandas as pd

# %%
data=pd.read_csv('Dataset.csv')

# %%
data.describe()
# Out:
#               Ad_No         Price    Model_Year        Mileage
# count  4.491700e+04  4.491700e+04  44917.000000   44917.000000
# mean   4.086715e+06  2.131077e+06   2011.504931   89229.394817
# std    1.576541e+05  2.963947e+06      6.120335   62760.401087
# min    1.338100e+04  1.110000e+05   1990.000000       1.000000
# 25%    4.066368e+06  9.500000e+05   2007.000000   46500.000000
# 50%    4.103356e+06  1.530000e+06   2013.000000   80000.000000
# 75%    4.142525e+06  2.400000e+06   2016.000000  120000.000000
# max    4.168339e+06  7.750000e+07   2019.000000  999999.000000

# %%
price=data['Price']
mileage=data['Mileage']
model=data['Model_Year']

# %%
price
# Out:
# 0          111000
# 1          123000
# 2          123000
# 3          140000
# 4          150000
#            ...
# 44912    58500000
# 44913    65000000
# 44914    65000000
# 44915    66000000
# 44916    77500000
# Name: Price, Length: 44917, dtype: int64

# %%
mileage
# Out:
# 0         11111
# 1        123456
# 2         97000
# 3        100000
# 4        120000
#           ...
# 44912        84
# 44913     10000
# 44914     17000
# 44915     22000
# 44916     17500
# Name: Mileage, Length: 44917, dtype: int64

# %%
model
# Out:
# 0        2019
# 1        1998
# 2        2017
# 3        1996
# 4        1990
#          ...
# 44912    2019
# 44913    2018
# 44914    2018
# 44915    2018
# 44916    2018
# Name: Model_Year, Length: 44917, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.title('price vs mileage')
plt.xlabel("price")
plt.ylabel("model year")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.style.use('classic')
plt.xlim(111000,77500000)
plt.ylim(1,999999)
plt.plot(price,mileage)
